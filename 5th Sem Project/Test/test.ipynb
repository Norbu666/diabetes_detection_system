# %%
import joblib
import numpy as np

# %%
model_path = r"C:\Users\Public\Downloads\5th Sem Project\MLModel\model.pkl"
scaler_path = r"C:\Users\Public\Downloads\5th Sem Project\MLModel\scaler.pkl"

# %%
model = joblib.load(model_path)
scaler = joblib.load(scaler_path)

# %%
# user_data = [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age]
user_data = np.array([[4,110,92,0,0,37.6,0.191,30]])

user_data_scaled = scaler.transform(user_data)
# Out:
# c:\Users\ashra\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction = model.predict(user_data_scaled)

if prediction[0] == 1:
    print("\nResult: The patient has diabetes.")
else:
    print("\nResult: The patient does not have diabetes.")
# Out:
# Result: The patient does not have diabetes.

# %%
import joblib
scaler = joblib.load("C:\\Users\\Public\\Downloads\\5th Sem Project\\MLModel\\model.pkl")


print(type(scaler))
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
